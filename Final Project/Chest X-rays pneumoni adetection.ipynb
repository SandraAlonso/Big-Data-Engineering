# %% [markdown]
# # **Pneumonia identification from X-Ray images**
# ---
# **Authors: Sandra Alonso Paz and Lobna Ramadane Morchadi**
#
# Pneumonia is an inflammation of the lung tissue caused by an infection that can lead to serious health problems and even death [1]. Although bacteria are the most common causes of pneumonia, it can also be caused by viruses, fungi, and other agents.
#
# Focussing on the principal symptoms of this disease, they can vary among children, adults and older people. However, the most common symptoms include  shaking chills, fever, chest pain, cough, night sweats, nausea, vomiting, muscle aches, rapid breathing and heartbeat, shortness of breath, confusion, and weight loss.
#
# Pneumonia treatment generally involves determining the need for: hospitalization, antibiotics, supportive care, and follow-up care. Although most adults do not need to be hospitalized for pneumonia, it is mandatory to follow a home-care treatment which involves:  drinking fluids, monitoring body temperature, allowing the cough reflex to clear the lung (no cough suppression), pain relief (if needed), finishing the entire course of antibiotics (if applicable), and not smoking. In other cases, if hospitalization is needed, the standard treatment is intravenous antibiotics.
#
# Luckily as earlier is diagnosed this disease, as faster a treatment will be chosen and consequently, less aggressive would be the pneumonia. Principal diagnosis procedures are taking into account patient history, performing physical examination and laboratory tests, and imaging. In this last one is where our work fits.
#
# Nowadays, one of the applications of ML models are clinical-decision support algorithms for medical imaging diagnosis. Even though it is highly challenging to obtain algorithms with an important reliability and interpretability, the aim of this project is to build a diagnostic tool based in deep-learning using pySpark and AnaliticsZoo.
#
# We will apply this approach to a dataset containing chest X-ray images for the diagnosis of pediatric pneumonia. This tool may aid in the diagnosis facilitating early treatment, resulting in improved clinical outcomes and help for clinical interpretability and support to the human expertise.
#
# As mentioned, a key element for diagnosis is radiographic data: chest X-rays. These are routinely obtained and can help to differentiate between viral and bacterial pneumonia. But, a fast radiologic interpretation is not always possible, especially in low-resource settings. For that purpose, **we have developed an effective supervised machine learning framework to classify pediatric chest X-rays to detect pneumonia and facilitate rapid diagnosis and treatment.**
#
# In this sense, we have followed in some way steps proposed in Analytics Zoo documentation which can be consulted in [2]

# %% [markdown]
# # Step 0: Prepare Environment
#
# Requirements for the execution:
#
# * Install jdk8
# * Install latest pre-release version of Analytics Zoo with RayOnSpark

# %%
# Install jdk8
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
import os
# Set environment variable JAVA_HOME.
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# Out:
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode
# openjdk version "1.8.0_312"
# OpenJDK Runtime Environment (build 1.8.0_312-8u312-b07-0ubuntu1~18.04-b07)
# OpenJDK 64-Bit Server VM (build 25.312-b07, mixed mode)

# %%
# Install latest pre-release version of Analytics Zoo with RayOnSpark
# Installing Analytics Zoo from pip will automatically install pyspark, bigdl, and their dependencies.
# !pip install --pre --upgrade analytics-zoo[ray]
# Out:
# Collecting analytics-zoo[ray]
#   Downloading analytics_zoo-0.12.0b2022022201-py2.py3-none-manylinux1_x86_64.whl (194.7 MB)
#      |████████████████████████████████| 194.7 MB 65 kB/s
# Collecting bigdl==0.13.1.dev0
#   Downloading BigDL-0.13.1.dev0-py2.py3-none-manylinux1_x86_64.whl (114.0 MB)
#      |████████████████████████████████| 114.0 MB 29 kB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from analytics-zoo[ray]) (3.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from analytics-zoo[ray]) (21.3)
# Collecting pyspark==2.4.6
#   Downloading pyspark-2.4.6.tar.gz (218.4 MB)
#      |████████████████████████████████| 218.4 MB 55 kB/s
# Collecting conda-pack==0.3.1
#   Downloading conda_pack-0.3.1-py2.py3-none-any.whl (27 kB)
# Collecting aioredis==1.1.0
#   Downloading aioredis-1.1.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.6 MB/s
# Collecting aiohttp==3.7.0
#   Downloading aiohttp-3.7.0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 38.8 MB/s
# Collecting setproctitle
#   Downloading setproctitle-1.2.2-cp37-cp37m-manylinux1_x86_64.whl (36 kB)
# Collecting ray==1.2.0
#   Downloading ray-1.2.0-cp37-cp37m-manylinux2014_x86_64.whl (47.5 MB)
#      |████████████████████████████████| 47.5 MB 1.7 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from analytics-zoo[ray]) (5.4.8)
# Collecting hiredis==1.1.0
#   Downloading hiredis-1.1.0-cp37-cp37m-manylinux2010_x86_64.whl (62 kB)
#      |████████████████████████████████| 62 kB 513 kB/s
# Collecting async-timeout==3.0.1
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.0->analytics-zoo[ray]) (3.0.4)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.2 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 65.4 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.7.0->analytics-zoo[ray]) (21.4.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from bigdl==0.13.1.dev0->analytics-zoo[ray]) (1.21.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from bigdl==0.13.1.dev0->analytics-zoo[ray]) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from conda-pack==0.3.1->analytics-zoo[ray]) (57.4.0)
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 45.3 MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (4.3.3)
# Collecting redis>=3.5.0
#   Downloading redis-4.2.0rc1-py3-none-any.whl (220 kB)
#      |████████████████████████████████| 220 kB 59.4 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (7.1.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (1.0.3)
# Collecting gpustat
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 195 kB/s
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.4.0.dev1-py2.py3-none-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 47.9 MB/s
# Collecting colorful
#   Downloading colorful-0.6.0a1-py2.py3-none-any.whl (202 kB)
#      |████████████████████████████████| 202 kB 53.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (2.23.0)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (1.43.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (3.17.3)
# Collecting opencensus
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 55.3 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (3.13)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray==1.2.0->analytics-zoo[ray]) (0.13.1)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting redis>=3.5.0
#   Downloading redis-4.1.4-py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 55.7 MB/s
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray==1.2.0->analytics-zoo[ray]) (4.11.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray==1.2.0->analytics-zoo[ray]) (1.13.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray==1.2.0->analytics-zoo[ray]) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray==1.2.0->analytics-zoo[ray]) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->analytics-zoo[ray]) (3.0.7)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.7.0->analytics-zoo[ray]) (2.10)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray==1.2.0->analytics-zoo[ray]) (7.352.0)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.2 MB/s
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.17.1->gpustat->ray==1.2.0->analytics-zoo[ray]) (0.2.5)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray==1.2.0->analytics-zoo[ray]) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray==1.2.0->analytics-zoo[ray]) (0.18.1)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray==1.2.0->analytics-zoo[ray]) (1.26.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->analytics-zoo[ray]) (2018.9)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->analytics-zoo[ray]) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->analytics-zoo[ray]) (1.54.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->analytics-zoo[ray]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->analytics-zoo[ray]) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->analytics-zoo[ray]) (4.2.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->analytics-zoo[ray]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray==1.2.0->analytics-zoo[ray]) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray==1.2.0->analytics-zoo[ray]) (1.24.3)
# Building wheels for collected packages: pyspark, gpustat
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.6-py2.py3-none-any.whl size=218814407 sha256=ceab036055c0e612ada18f9dbb89fb7fc63a2c894e2aefeb463229dedfb1c14a
#   Stored in directory: /root/.cache/pip/wheels/f1/42/b0/ba397759613f4feb1611021a2503e60e344e546671b2ae04f8
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=e083b568d1de9a826df5867a385f0961bed98b50f6e53870445aea1e3bb1032e
#   Stored in directory: /root/.cache/pip/wheels/1a/16/e2/3e2437fba4c4b6a97a97bd96fce5d14e66cff5c4966fb1cc8c
# Successfully built pyspark gpustat
# Installing collected packages: multidict, yarl, py4j, async-timeout, pyspark, opencensus-context, hiredis, deprecated, blessed, aiohttp, redis, py-spy, opencensus, gpustat, conda-pack, colorful, colorama, bigdl, aioredis, aiohttp-cors, setproctitle, ray, analytics-zoo
# Successfully installed aiohttp-3.7.0 aiohttp-cors-0.7.0 aioredis-1.1.0 analytics-zoo-0.12.0b2022022201 async-timeout-3.0.1 bigdl-0.13.1.dev0 blessed-1.19.1 colorama-0.4.4 colorful-0.6.0a1 conda-pack-0.3.1 deprecated-1.2.13 gpustat-1.0.0b1 hiredis-1.1.0 multidict-6.0.2 opencensus-0.8.0 opencensus-context-0.1.2 py-spy-0.4.0.dev1 py4j-0.10.7 pyspark-2.4.6 ray-1.2.0 redis-4.1.4 setproctitle-1.2.2 yarl-1.7.2

# %% [markdown]
# # Step 1: Init Orca Context
#
# Most Artificial Intelligence projects start with a Python notebook running on a single laptop; however, one usually needs to go through a mountain of pains to scale it to handle larger data set in a distributed fashion. The Orca library seamlessly scales out your single node TensorFlow or PyTorch notebook across large clusters (so as to process distributed Big Data).
#
# Ray is an open source distributed framework for emerging AI applications. It allows users to directly run Ray programs on existing Big Data clusters, and directly write Ray code inline with their Spark code (so as to process the in-memory Spark RDDs or DataFrames).
#
# ## First, we should import necessary libraries and modules

# %%
# Orca libraries:
from zoo.orca import init_orca_context, stop_orca_context
from zoo.orca import OrcaContext

# Model creation libraries:
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.optimizers import Adam

# Image pre-processing libraries:
import os
from PIL import Image
import torchvision
import torchvision.transforms as T

# Dataset creation libraries:
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Result evaluation libraries:
import matplotlib.pyplot as plt

# %% [markdown]
# ## Then, let's initialize Orca context

# %%
# It is recommended to set it to True when running Analytics Zoo in Jupyter notebook 
OrcaContext.log_output = True # (this will display terminal's stdout and stderr in the Jupyter notebook).

init_orca_context(cluster_mode="local", cores=6)
# Out:
# Initializing orca context
# Current pyspark location is : /usr/local/lib/python3.7/dist-packages/pyspark/__init__.py
# Start to getOrCreate SparkContext
# pyspark_submit_args is:  --driver-class-path /usr/local/lib/python3.7/dist-packages/zoo/share/lib/analytics-zoo-bigdl_0.13.1-SNAPSHOT-spark_2.4.6-0.12.0-SNAPSHOT-jar-with-dependencies.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/lib/bigdl-0.13.1-SNAPSHOT-jar-with-dependencies.jar pyspark-shell
# 2022-02-22 17:10:24 WARN  NativeCodeLoader:62 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# cls.getname: com.intel.analytics.bigdl.python.api.Sample
# BigDLBasePickler registering: bigdl.util.common  Sample
# cls.getname: com.intel.analytics.bigdl.python.api.EvaluatedResult
# BigDLBasePickler registering: bigdl.util.common  EvaluatedResult
# cls.getname: com.intel.analytics.bigdl.python.api.JTensor
# BigDLBasePickler registering: bigdl.util.common  JTensor
# cls.getname: com.intel.analytics.bigdl.python.api.JActivity
# BigDLBasePickler registering: bigdl.util.common  JActivity
# Successfully got a SparkContext
# User settings:
#
#    KMP_AFFINITY=granularity=fine,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_SETTINGS=1
#    OMP_NUM_THREADS=1
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_HAND_THREAD=false
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=false
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_FORKJOIN_FRAMES=true
#    KMP_FORKJOIN_FRAMES_MODE=3
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_ITT_PREPARE_DELAY=0
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_MWAIT_HINTS=0
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=2
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USER_LEVEL_MWAIT=false
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=true
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEBUG=disabled
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=2147483647
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED=false
#    OMP_NUM_THREADS='1'
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_TOOL=enabled
#    OMP_TOOL_LIBRARIES: value is not defined
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
# <SparkContext master=local[6] appName=pyspark-shell>

# %% [markdown]
# ## Now it is time to perform data-parallel processing in Orca.

# %%
# This supports standard Spark Dataframes, TensorFlow Dataset, PyTorch DataLoader, Pandas, Pillow, etc.
spark = OrcaContext.get_spark_session()

# %% [markdown]
# # Step 2: Define the Model

# %% [markdown]
#
# After consulting several resources we came up with the conclusion that Transfer learning was the best choice for solving the proposed problem.
#
# ## 2.1. What is Transfer Learning?
# **Transfer learning** is a machine learning method where a model developed for a task is reused as the starting point for a model on a second task.
# It is a popular approach in deep learning where pre-trained models are used as the starting point on computer vision given the vast compute and time resources required to develop neural network models on these problems and from the huge jumps in skill that they provide on related problems. [3]
#
# ## 2.2. What is ResNet?
#
# ResNet stands for Residual Network. It is an innovative neural network that was first introduced by Kaiming He, Xiangyu Zhang, Shaoqing Ren, and Jian Sun in their 2015 computer vision research paper titled ‘Deep Residual Learning for Image Recognition’ [4].
#
# ## 2.3. What is ResNet-50?
#
# ResNet has many variants that run on the same concept but have different numbers of layers. Resnet50 is used to denote the variant that can work with 50 neural network layers. [5]
#
# ## 2.4. Deep Neural Networks in Computer Vision
#
# When working with deep convolutional neural networks to solve a problem related to computer vision, machine learning experts engage in stacking more layers. These additional layers help solve complex problems more efficiently as the different layers could be trained for varying tasks to get highly accurate results.
#
# While the number of stacked layers can enrich the features of the model, a deeper network can show the issue of degradation. In other words, **as the number of layers of the neural network increases, the accuracy levels may get saturated and slowly degrade after a point**. As a result, the performance of the model deteriorates both on the training and testing data.
#
# This degradation is not a result of overfitting. Instead, it may result from the initialization of the network, optimization function, or, more importantly, the problem of vanishing or exploding gradients.
#
# **ResNet was created with the aim of tackling this exact problem**. Deep residual nets make use of residual blocks to improve the accuracy of the models. The concept of “skip connections,” which lies at the core of the residual blocks, is the strength of this type of neural network.
#
# ## 2.5. Resnet50 with Keras
#
# Keras is a deep learning API that is popular due to the simplicity of building models using it. Keras comes with several pre-trained models, including Resnet50, that anyone can use for their experiments.
#
# Therefore, building a residual network in Keras for computer vision tasks like image classification is relatively simple.

# %%
# References used while creating the model:
  # Create a model based on Zoo Keras: 
  #        https://github.com/intel-analytics/analytics-zoo/blob/master/docs/docs/ProgrammingGuide/workingwithimages.md

  # Net type and parameters:
  #       https://keras.io/api/applications/resnet/#resnet50-function
  #       https://www.delltechnologies.com/asset/en-us/solutions/industry-solutions/industry-market/h17686_hornet_wp.pdf

  # Transfer learning:
  #        https://medium.com/@kenneth.ca95/a-guide-to-transfer-learning-with-keras-using-resnet50-a81a4a28084b
  #        https://chroniclesofai.com/transfer-learning-with-keras-resnet-50/

def model_creator(config):
  # Pre-trained model
   res_model = tf.keras.applications.ResNet50(include_top=False, weights="imagenet", input_tensor=None,
                                               input_shape=(224, 224, 3), pooling=None)
   # Create and model based on pretrained model
   model = K.models.Sequential()
   model.add(res_model)
   # Flatten reshapes the tensor to have a shape that is equal to the number of elements contained in the tensor (making a 1d-array of elements)
   model.add(K.layers.Flatten())
   # Dense implements the operation: output = activation(dot(input, kernel) + bias) where activation has been setted at sigmoid
   model.add(K.layers.Dense(1, activation='sigmoid'))
   # Compile the model means configure the model. For this task we have selected categorical_crossentropy as loss and the adam optimizer (see below).
   # As we want to study our result we will need to obtain the accuracy, precission and recall which are the most important parameter in this terms
   model.compile( loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001),
                  metrics=['Accuracy', 
                  keras.metrics.AUC(),
                  tf.keras.metrics.Precision(), 
                  tf.keras.metrics.Recall(),
                  tf.keras.metrics.TruePositives(),
                  tf.keras.metrics.TrueNegatives(),
                  tf.keras.metrics.FalsePositives(),
                  tf.keras.metrics.FalseNegatives()])
   # Model has been created
   return model

# %% [markdown]
# ## What is the Adam optimization algorithm?
# Adam is an optimization algorithm that can be used instead of the classical stochastic gradient descent procedure to update network weights iterative based in training data.
#
# When introducing the algorithm, the authors list the attractive benefits of using Adam on non-convex optimization problems, as follows:
#
# * Straightforward to implement.
# * Computationally efficient.
# * Little memory requirements.
# * Invariant to diagonal rescale of the gradients.
# * Well suited for problems that are large in terms of data and/or parameters.
#
# In this sense we made use of Adam optimzer instead of RMSprop proposed on the followed guide [6]

# %% [markdown]
# # Step 3: Define Train Dataset

# %% [markdown]
# Our dataset is made up of three image folders (train, test and validation). Each one has two folders inside which contain classified 5232 images of 1349 "NORMAL" X-RAY images and "PNEUMONIA" X-RAY images.
#
#
# This dataset has been upload to our personal Drive for facilitating data handling accounts but can also be downloaded in [Kaggle](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# In order to develop a user-friendly code, we have save the different paths we will use 
# during the devlopment process.
train_images= '/content/drive/MyDrive/UPM/chest_xray/train'
val_images = '/content/drive/MyDrive/UPM/chest_xray/val/'
test_images = '/content/drive/MyDrive/UPM/chest_xray/test/'

# %% [markdown]
# ## 3.1. Data visualization

# %% [markdown]
# ### 3.1.1 Train data

# %%
normal_df_train = spark.read.format("image").load(train_images+'/NORMAL')
pneumonia_df_train = spark.read.format("image").load(train_images+'/PNEUMONIA')

# %%
print("Schema of normal dataframe of training set")
normal_df_train.printSchema()
print("Image labeled sample ")
normal_df_train.show(5)
print("Number of images in the normal training dataframe: ")
normal_df_train.select("image").count()
# Out:
# Schema of normal dataframe of training set
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)
#
# Image labeled sample
# +--------------------+
# |               image|
# +--------------------+
# |[file:///content/...|
# |[file:///content/...|
# |[file:///content/...|
# |[file:///content/...|
# |[file:///content/...|
# +--------------------+
# only showing top 5 rows
#
# Number of images in the normal training dataframe:
# 1341

# %%
print("Schema of pneumonia dataframe of training set")
pneumonia_df_train.printSchema()
print("Image labeled sample ")
pneumonia_df_train.show(5)
print("Number of images in the pneumonia training dataframe: ")
pneumonia_df_train.select("image").count()
# Out:
# Schema of pneumonia dataframe of training set
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)
#
# Image labeled sample
# +--------------------+
# |               image|
# +--------------------+
# |[file:///content/...|
# |[file:///content/...|
# |[file:///content/...|
# |[file:///content/...|
# |[file:///content/...|
# +--------------------+
# only showing top 5 rows
#
# Number of images in the pneumonia training dataframe:
# 3875

# %%
train_df = normal_df_train.unionAll(pneumonia_df_train)

# Count all the images storaged
print('Number of training images: ', train_df.count())
print('Number of training NORMAL images: ', normal_df_train.count(), " or" ,(normal_df_train.count()/ train_df.count()), "%")
print('Number of training PNEUMONIA images: ', pneumonia_df_train.count(), " or", (pneumonia_df_train.count()/train_df.count()), "%")
# Out:
# Number of training images:  5216
# Number of training NORMAL images:  1341  or 0.2570935582822086 %
# Number of training PNEUMONIA images:  3875  or 0.7429064417177914 %

# %%
# First it is mandatory study image format
train_df.select("image.origin", "image.width", "image.height").show(truncate=False)
# As width and height are not standardized we will start pre-processing
# Out:
# [Stage 20:>                                                         (0 + 1) / 1]
# +----------------------------------------------------------------------------------------+-----+------+
# |origin                                                                                  |width|height|
# +----------------------------------------------------------------------------------------+-----+------+
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1257-0001.jpeg     |2916 |2583  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1018-0001.jpeg     |2694 |2625  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1050-0001.jpeg     |2564 |2519  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0602-0001.jpeg     |2619 |2628  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1302-0001.jpeg     |2721 |2438  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0774-0001.jpeg     |2510 |2543  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0957-0001.jpeg     |2633 |2578  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1258-0001.jpeg     |2482 |2570  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0001.jpeg|2428 |2540  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0002.jpeg|2428 |2540  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0927-0001.jpeg     |2359 |2234  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0828-0001.jpeg     |2553 |2305  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1038-0001.jpeg     |2309 |2601  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0994-0001.jpeg     |2373 |2663  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0441-0001.jpeg     |2288 |2363  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1052-0001.jpeg     |2340 |2431  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0904-0001.jpeg     |2534 |2169  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0899-0001.jpeg     |2427 |2374  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-0944-0001.jpeg     |2566 |2321  |
# |file:///content/drive/MyDrive/UPM/chest_xray/train/NORMAL/IM-0533-0001.jpeg             |2518 |2364  |
# +----------------------------------------------------------------------------------------+-----+------+
# only showing top 20 rows

# %% [markdown]
# ### 3.1.2. Test data

# %%
# For future steps we will store the rest of the data given
normal_df_test = spark.read.format("image").load(test_images+'/NORMAL')
pneumonia_df_test = spark.read.format("image").load(test_images+'/PNEUMONIA')
test_df = normal_df_test.unionAll(pneumonia_df_test)

# Count all the images storaged
print('Number of testing images: ', test_df.count())
print('Number of testing NORMAL images: ', normal_df_test.count(), " or" ,(normal_df_test.count()/ test_df.count()), "%")
print('Number of testing PNEUMONIA images: ', pneumonia_df_test.count(), " or", (pneumonia_df_test.count()/test_df.count()), "%")
# Out:
# Number of testing images:  624
# Number of testing NORMAL images:  234  or 0.375 %
# Number of testing PNEUMONIA images:  390  or 0.625 %

# %% [markdown]
# ### 3.1.3. Validation data

# %%
normal_df_val = spark.read.format("image").load(val_images+'/NORMAL')
pneumonia_df_val = spark.read.format("image").load(val_images+'/PNEUMONIA')
val_df = normal_df_val.unionAll(pneumonia_df_val)

# Count all the images storaged
print('Number of validation images: ', val_df.count())
print('Number of validation NORMAL images: ', normal_df_val.count(), " or" ,(normal_df_val.count()/ val_df.count()), "%")
print('Number of validation PNEUMONIA images: ', pneumonia_df_val.count(), " or", (pneumonia_df_val.count()/val_df.count()), "%")
# Out:
# Number of validation images:  16
# Number of validation NORMAL images:  8  or 0.5 %
# Number of validation PNEUMONIA images:  8  or 0.5 %

# %% [markdown]
# ## 3.2. Preprocessing

# %% [markdown]
# Image pre-processing are steps which involve formatting images before they are used by the model training. This usually includes: resizing, orienting and color corrections.
#
# As we are using fully connected layers in convolutional neural networks, these require that all images are the same sized arrays. Most architectures require a squared image entry, but in very few situations we have images with that format. In this sense we have used resize() function for resizing all images in 1024 x 1024. Moreover we have used CenterCrop() function for focussing on the center of the chest x ray image where usually the anomalies we want to find are placed.
#
# On the other hand, color changes are a type of image transformation that is generally applied to all the dataset (train and test). Being more timely performance when images are grayscaled. Color images are stored as red, green and blue values, while grayscale images are only stored as a range of white to black. This means only need to work with one matrix per image, and not three as in color images occurs [7]. In this sense, we tried to use a greyscale. However ResNet50 only accepts 3 input channels so finally, we used rgb scale.
#
# Finally, we have included the function ColorJitter which adjust brightness and contrast.

# %%
# Firstly we have defined a function (which will be called later) to include all the preprocessing function we want to apply.
# In our case:
# 1. CenterCrop() to focuss on the center of the image
# 2. RandomHorizontalFlip() to randomly flip the image (0.5 = 50%)
# 3. ColorJitter() which manages the brightness and contrast of the image
def define_transformer(sample):
  transformer = torchvision.transforms.Compose([T.CenterCrop(224), T.RandomHorizontalFlip(p=0.5), T.ColorJitter(brightness=0.5, contrast=0.1,hue=0)])
  return transformer(sample)

# %%
# Here we resize y call define_transformer function for each all the paths and its images

def processing (path):
  path_types = ['/NORMAL/', '/PNEUMONIA/']
  for t in path_types:
    for img in os.listdir(path+t): # For all the images contained in the folders
        image = Image.open(path+t+img) # We use PIL functions to manage the images
        new_image = image.resize((1024, 1024)) # Resize to a proper and common size
        define_transformer(new_image).save(path+'/processed/'+t+img) # Save the result in a new folder for using them in training and testing

# %%
# Perform the pre-processing process for all the paths
paths = [train_images, val_images, test_images]
for p in paths:
    processing(p)

# %%
# New paths for processed images
train_images= '/content/drive/MyDrive/UPM/chest_xray/train/processed'
val_images = '/content/drive/MyDrive/UPM/chest_xray/val/processed'
test_images = '/content/drive/MyDrive/UPM/chest_xray/test/processed'

# %% [markdown]
# Here are some examples of the pre-processing process:

# %%
print('Image NORMAL2-IM-1308-0001.jpeg before pre-processing')
image = Image.open('/content/drive/MyDrive/UPM/chest_xray/train/NORMAL/NORMAL2-IM-1308-0001.jpeg')
image.show()
# Out:
# Image NORMAL2-IM-1308-0001.jpeg before pre-processing

# %%
print('Image NORMAL2-IM-1308-0001.jpeg before post-processing')
image = Image.open(train_images+'/NORMAL/NORMAL2-IM-1308-0001.jpeg')
image.show()
# Out:
# Image NORMAL2-IM-1308-0001.jpeg before post-processing

# %% [markdown]
# ## 3.3. Create Dataset for future training and testing

# %% [markdown]
# In order to use given images in our model, it was mandatory to create Datasets of each processed image folder. For this task we have made use of image_dataset_from_directory() function which generates a tf.data.Dataset from image files in a directory. In addition, we could include some characteristics of the images such as their class, size and label.

# %%
# Function extracted from 
#       https://analytics-zoo.readthedocs.io/en/latest/doc/Orca/QuickStart/orca-tf2keras-quickstart.html and
#       https://keras.io/api/preprocessing/image/def train_data_creator(config, batch_size):

#-------------------------------------- TRAIN DATASET ------------------------------------------------------------------------------------------
    
def train_data_creator(config, batch_size):

    train_ds = image_dataset_from_directory(train_images, 
                                            labels= 'inferred',                     # labels are generated from the directory structure
                                            label_mode='binary',                    #  means that the labels can be only 2
                                            # !! important !! in other versions you could chose float32  as label mode. However is not usable any more
                                            # But it is mandatory to convert later this type
                                            class_names = ['NORMAL', 'PNEUMONIA'],
                                            image_size=(224, 224),                 # Shape has been defined before as 224x224 after cropping images so we set this param to not resize again
                                            batch_size = 1,                        # Size of the batches of data.
                                            shuffle=False)
                                            

    # Duplication of the train dataset
    train_ds = train_ds.repeat(2)

    # map function is frequently used for applying a characteristic or method to set of data. In our case we need to perform three:
    # 1. Perform the preproces proper to Resnet50 
    train_ds = train_ds.map(lambda x, y: (K.applications.resnet50.preprocess_input(x), y))
    # 2. Finally, it is mandatory to cast (change type) to float32 (as explained above (label_mode = binary)) in order to avoid converse problems
    train_ds = train_ds.map(lambda x, y: (tf.cast(x, dtype = tf.float32), y))
    return train_ds

#-------------------------------------- VALIDATION DATASET ---------------------------------------------------------------------------------------

def val_data_creator(config, batch_size):
    val_ds = image_dataset_from_directory(val_images, 
                                          labels = 'inferred',
                                          label_mode='binary',
                                          class_names = ['NORMAL', 'PNEUMONIA'],
                                          image_size=(224, 224), 
                                          batch_size = 1,
                                          shuffle=False)                                        
                                            
    val_ds = val_ds.repeat(2)
    val_ds = val_ds.map(lambda x, y: (K.applications.resnet50.preprocess_input(x), y))
    val_ds = val_ds.map(lambda x, y: (tf.cast(x, dtype = tf.float32), y))
    return val_ds

#-------------------------------------- TEST DATASET ---------------------------------------------------------------------------------------------


def test_data_creator(config, batch_size):
    test_ds = image_dataset_from_directory(test_images, 
                                            label_mode='binary',
                                            class_names = ['NORMAL', 'PNEUMONIA'],
                                            image_size=(224, 224), 
                                            batch_size = batch_size,
                                            shuffle=True)                                          
                                           
   
    test_ds = test_ds.repeat(2)
    test_ds = test_ds.map(lambda x, y: (K.applications.resnet50.preprocess_input(x), y))
    test_ds = test_ds.map(lambda x, y: (tf.cast(x, dtype = tf.float32), y))
    return test_ds

# %% [markdown]
# # Step 4: Fit with Orca Estimator

# %% [markdown]
# ## 4.1. First we created an Estimator

# %%
from zoo.orca.learn.tf2.estimator import Estimator
from tensorflow import keras
import keras

est = Estimator.from_keras(model_creator = model_creator)
# Out:
# 2022-02-22 18:09:55,753	INFO services.py:1174 -- View the Ray dashboard at http://172.28.0.2:8265
# {'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': '172.28.0.2:6379', 'object_store_address': '/tmp/ray/session_2022-02-22_18-09-54_643664_72/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-02-22_18-09-54_643664_72/sockets/raylet', 'webui_url': '172.28.0.2:8265', 'session_dir': '/tmp/ray/session_2022-02-22_18-09-54_643664_72', 'metrics_export_port': 63615, 'node_id': 'c64c913983015a6d4d789faf23666445c6de02099e2e5d9220cabb99'}
# (pid=5233) WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/zoo/orca/learn/tf2/tf_runner.py:317: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# (pid=5233) Instructions for updating:
# (pid=5233) use distribute.MultiWorkerMirroredStrategy instead
# (pid=5233) 2022-02-22 18:10:08.865923: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=5233) Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
#    16384/94765736 [..............................] - ETA: 0s
#  4628480/94765736 [>.............................] - ETA: 0s
# 10338304/94765736 [==>...........................] - ETA: 0s
# 15687680/94765736 [===>..........................] - ETA: 0s
# 20971520/94765736 [=====>........................] - ETA: 0s
# 27942912/94765736 [=======>......................] - ETA: 0s
# 35528704/94765736 [==========>...................] - ETA: 0s
# 42647552/94765736 [============>.................] - ETA: 0s
# 49061888/94765736 [==============>...............] - ETA: 0s
# 56410112/94765736 [================>.............] - ETA: 0s
# 64012288/94765736 [===================>..........] - ETA: 0s
# 71524352/94765736 [=====================>........] - ETA: 0s
# 77758464/94765736 [=======================>......] - ETA: 0s
# 83484672/94765736 [=========================>....] - ETA: 0s
# 87228416/94765736 [==========================>...] - ETA: 0s
# 90562560/94765736 [===========================>..] - ETA: 0s
# 92741632/94765736 [============================>.] - ETA: 0s
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# ## 4.2. Then, we evaluate the model using the Estimator

# %%
batch_size = 320
stats = est.fit(train_data_creator,
                epochs=1,
                batch_size=batch_size,
                validation_data= val_data_creator)
# Out:
# (pid=5233) Found 5216 files belonging to 2 classes.
# (pid=5233) WARNING:tensorflow:AutoGraph could not transform <function train_data_creator.<locals>.<lambda> at 0x7f7205bd3ef0> and will run it as-is.
# (pid=5233) Cause: could not parse the source code of <function train_data_creator.<locals>.<lambda> at 0x7f7205bd3ef0>: no matching AST found among candidates:
# (pid=5233)
# (pid=5233) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=5233) WARNING:tensorflow:AutoGraph could not transform <function train_data_creator.<locals>.<lambda> at 0x7f7205bd3dd0> and will run it as-is.
# (pid=5233) Cause: could not parse the source code of <function train_data_creator.<locals>.<lambda> at 0x7f7205bd3dd0>: no matching AST found among candidates:
# (pid=5233)
# (pid=5233) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=5233) WARNING:tensorflow:AutoGraph could not transform <function val_data_creator.<locals>.<lambda> at 0x7f7203b7ff80> and will run it as-is.
# (pid=5233) Cause: could not parse the source code of <function val_data_creator.<locals>.<lambda> at 0x7f7203b7ff80>: no matching AST found among candidates:
# (pid=5233)
# (pid=5233) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=5233) WARNING:tensorflow:AutoGraph could not transform <function val_data_creator.<locals>.<lambda> at 0x7f7203b7ad40> and will run it as-is.
# (pid=5233) Cause: could not parse the source code of <function val_data_creator.<locals>.<lambda> at 0x7f7203b7ad40>: no matching AST found among candidates:
# (pid=5233)
# (pid=5233) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=5233) Found 16 files belonging to 2 classes.
# (pid=5233) 2022-02-22 18:10:15.563777: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_1"
# (pid=5233) op: "TensorSliceDataset"
# (pid=5233) input: "Placeholder/_0"
# (pid=5233) attr {
# (pid=5233)   key: "Toutput_types"
# (pid=5233)   value {
# (pid=5233)     list {
# (pid=5233)       type: DT_STRING
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "_cardinality"
# (pid=5233)   value {
# (pid=5233)     i: 5216
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "is_files"
# (pid=5233)   value {
# (pid=5233)     b: false
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "metadata"
# (pid=5233)   value {
# (pid=5233)     s: "\n\024TensorSliceDataset:0"
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "output_shapes"
# (pid=5233)   value {
# (pid=5233)     list {
# (pid=5233)       shape {
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) experimental_type {
# (pid=5233)   type_id: TFT_PRODUCT
# (pid=5233)   args {
# (pid=5233)     type_id: TFT_DATASET
# (pid=5233)     args {
# (pid=5233)       type_id: TFT_PRODUCT
# (pid=5233)       args {
# (pid=5233)         type_id: TFT_TENSOR
# (pid=5233)         args {
# (pid=5233)           type_id: TFT_STRING
# (pid=5233)         }
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233)   args {
# (pid=5233)     type_id: TFT_DATASET
# (pid=5233)     args {
# (pid=5233)       type_id: TFT_PRODUCT
# (pid=5233)       args {
# (pid=5233)         type_id: TFT_TENSOR
# (pid=5233)         args {
# (pid=5233)           type_id: TFT_STRING
# (pid=5233)         }
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233)
# (pid=5233) 2022-02-22 18:10:15.928463: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  5432/10432 [==============>...............] - ETA: 1:34:30 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1553.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5433/10432 [==============>...............] - ETA: 1:34:29 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1554.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5434/10432 [==============>...............] - ETA: 1:34:28 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1555.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5435/10432 [==============>...............] - ETA: 1:34:27 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1556.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5436/10432 [==============>...............] - ETA: 1:34:26 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1557.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5437/10432 [==============>...............] - ETA: 1:34:24 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1558.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5438/10432 [==============>...............] - ETA: 1:34:23 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1559.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5439/10432 [==============>...............] - ETA: 1:34:22 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1560.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5440/10432 [==============>...............] - ETA: 1:34:21 - loss: 0.0503 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1561.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5441/10432 [==============>...............] - ETA: 1:34:20 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1562.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5442/10432 [==============>...............] - ETA: 1:34:19 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1563.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5443/10432 [==============>...............] - ETA: 1:34:18 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1564.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5444/10432 [==============>...............] - ETA: 1:34:17 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1565.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5445/10432 [==============>...............] - ETA: 1:34:15 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1566.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5446/10432 [==============>...............] - ETA: 1:34:14 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1567.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5447/10432 [==============>...............] - ETA: 1:34:13 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1568.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5448/10432 [==============>...............] - ETA: 1:34:12 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1569.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5449/10432 [==============>...............] - ETA: 1:34:11 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1570.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5450/10432 [==============>...............] - ETA: 1:34:10 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1571.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5451/10432 [==============>...............] - ETA: 1:34:09 - loss: 0.0502 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1572.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5452/10432 [==============>...............] - ETA: 1:34:08 - loss: 0.0501 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1573.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5453/10432 [==============>...............] - ETA: 1:34:06 - loss: 0.0501 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1574.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5454/10432 [==============>...............] - ETA: 1:34:05 - loss: 0.0501 - Accuracy: 0.9983 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1575.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5455/10432 [==============>...............] - ETA: 1:34:04 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1576.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5456/10432 [==============>...............] - ETA: 1:34:03 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1577.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5457/10432 [==============>...............] - ETA: 1:34:02 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1578.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5458/10432 [==============>...............] - ETA: 1:34:01 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1579.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5459/10432 [==============>...............] - ETA: 1:34:00 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1580.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5460/10432 [==============>...............] - ETA: 1:33:59 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1581.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5461/10432 [==============>...............] - ETA: 1:33:57 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9983 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1582.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5462/10432 [==============>...............] - ETA: 1:33:56 - loss: 0.0501 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1583.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5463/10432 [==============>...............] - ETA: 1:33:55 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1584.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5464/10432 [==============>...............] - ETA: 1:33:54 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1585.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5465/10432 [==============>...............] - ETA: 1:33:53 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1586.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5466/10432 [==============>...............] - ETA: 1:33:52 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1587.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5467/10432 [==============>...............] - ETA: 1:33:51 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1588.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5468/10432 [==============>...............] - ETA: 1:33:50 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1589.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5469/10432 [==============>...............] - ETA: 1:33:49 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1590.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5470/10432 [==============>...............] - ETA: 1:33:48 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1591.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5471/10432 [==============>...............] - ETA: 1:33:47 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1592.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5472/10432 [==============>...............] - ETA: 1:33:45 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1593.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5473/10432 [==============>...............] - ETA: 1:33:44 - loss: 0.0500 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1594.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5474/10432 [==============>...............] - ETA: 1:33:43 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1595.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5475/10432 [==============>...............] - ETA: 1:33:42 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1596.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5476/10432 [==============>...............] - ETA: 1:33:41 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1597.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5477/10432 [==============>...............] - ETA: 1:33:40 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1598.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5478/10432 [==============>...............] - ETA: 1:33:39 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1599.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5479/10432 [==============>...............] - ETA: 1:33:38 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1600.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5480/10432 [==============>...............] - ETA: 1:33:37 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1601.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5481/10432 [==============>...............] - ETA: 1:33:35 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1602.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5482/10432 [==============>...............] - ETA: 1:33:34 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1603.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5483/10432 [==============>...............] - ETA: 1:33:33 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1604.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5484/10432 [==============>...............] - ETA: 1:33:32 - loss: 0.0499 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1605.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5485/10432 [==============>...............] - ETA: 1:33:31 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1606.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5486/10432 [==============>...............] - ETA: 1:33:30 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1607.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5487/10432 [==============>...............] - ETA: 1:33:29 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1608.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5488/10432 [==============>...............] - ETA: 1:33:28 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1609.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5489/10432 [==============>...............] - ETA: 1:33:26 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1610.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5490/10432 [==============>...............] - ETA: 1:33:25 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1611.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5491/10432 [==============>...............] - ETA: 1:33:24 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1612.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5492/10432 [==============>...............] - ETA: 1:33:23 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1613.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5493/10432 [==============>...............] - ETA: 1:33:22 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1614.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5494/10432 [==============>...............] - ETA: 1:33:21 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1615.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5495/10432 [==============>...............] - ETA: 1:33:20 - loss: 0.0498 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1616.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5496/10432 [==============>...............] - ETA: 1:33:18 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1617.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5497/10432 [==============>...............] - ETA: 1:33:17 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1618.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5498/10432 [==============>...............] - ETA: 1:33:16 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1619.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5499/10432 [==============>...............] - ETA: 1:33:15 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1620.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5500/10432 [==============>...............] - ETA: 1:33:14 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1621.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5501/10432 [==============>...............] - ETA: 1:33:13 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1622.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5502/10432 [==============>...............] - ETA: 1:33:12 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1623.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5503/10432 [==============>...............] - ETA: 1:33:10 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1624.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5504/10432 [==============>...............] - ETA: 1:33:09 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1625.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5505/10432 [==============>...............] - ETA: 1:33:08 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1626.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5506/10432 [==============>...............] - ETA: 1:33:07 - loss: 0.0497 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1627.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5507/10432 [==============>...............] - ETA: 1:33:06 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1628.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5508/10432 [==============>...............] - ETA: 1:33:05 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1629.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5509/10432 [==============>...............] - ETA: 1:33:04 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1630.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5510/10432 [==============>...............] - ETA: 1:33:03 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1631.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5511/10432 [==============>...............] - ETA: 1:33:01 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1632.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5512/10432 [==============>...............] - ETA: 1:33:00 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1633.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5513/10432 [==============>...............] - ETA: 1:32:59 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1634.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5514/10432 [==============>...............] - ETA: 1:32:58 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1635.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5515/10432 [==============>...............] - ETA: 1:32:57 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1636.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5516/10432 [==============>...............] - ETA: 1:32:56 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1637.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5517/10432 [==============>...............] - ETA: 1:32:55 - loss: 0.0496 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1638.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5518/10432 [==============>...............] - ETA: 1:32:54 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1639.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5519/10432 [==============>...............] - ETA: 1:32:53 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1640.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5520/10432 [==============>...............] - ETA: 1:32:51 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1641.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5521/10432 [==============>...............] - ETA: 1:32:50 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1642.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5522/10432 [==============>...............] - ETA: 1:32:49 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1643.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5523/10432 [==============>...............] - ETA: 1:32:48 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1644.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5524/10432 [==============>...............] - ETA: 1:32:47 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1645.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5525/10432 [==============>...............] - ETA: 1:32:46 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1646.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5526/10432 [==============>...............] - ETA: 1:32:45 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1647.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5527/10432 [==============>...............] - ETA: 1:32:44 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1648.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5528/10432 [==============>...............] - ETA: 1:32:43 - loss: 0.0495 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1649.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5529/10432 [==============>...............] - ETA: 1:32:41 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1650.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5530/10432 [==============>...............] - ETA: 1:32:40 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1651.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5531/10432 [==============>...............] - ETA: 1:32:39 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1652.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5532/10432 [==============>...............] - ETA: 1:32:38 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1653.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5533/10432 [==============>...............] - ETA: 1:32:37 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1654.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5534/10432 [==============>...............] - ETA: 1:32:36 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1655.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5535/10432 [==============>...............] - ETA: 1:32:35 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1656.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5536/10432 [==============>...............] - ETA: 1:32:34 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1657.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5537/10432 [==============>...............] - ETA: 1:32:33 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1658.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5538/10432 [==============>...............] - ETA: 1:32:31 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1659.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5539/10432 [==============>...............] - ETA: 1:32:30 - loss: 0.0494 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1660.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5540/10432 [==============>...............] - ETA: 1:32:29 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1661.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5541/10432 [==============>...............] - ETA: 1:32:28 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1662.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5542/10432 [==============>...............] - ETA: 1:32:27 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1663.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5543/10432 [==============>...............] - ETA: 1:32:26 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1664.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5544/10432 [==============>...............] - ETA: 1:32:25 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1665.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5545/10432 [==============>...............] - ETA: 1:32:24 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1666.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5546/10432 [==============>...............] - ETA: 1:32:22 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1667.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5547/10432 [==============>...............] - ETA: 1:32:21 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1668.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5548/10432 [==============>...............] - ETA: 1:32:20 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1669.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5549/10432 [==============>...............] - ETA: 1:32:19 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1670.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5550/10432 [==============>...............] - ETA: 1:32:18 - loss: 0.0493 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1671.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5551/10432 [==============>...............] - ETA: 1:32:17 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1672.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5552/10432 [==============>...............] - ETA: 1:32:16 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1673.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5553/10432 [==============>...............] - ETA: 1:32:15 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1674.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5554/10432 [==============>...............] - ETA: 1:32:13 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1675.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5555/10432 [==============>...............] - ETA: 1:32:12 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1676.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5556/10432 [==============>...............] - ETA: 1:32:11 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1677.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5557/10432 [==============>...............] - ETA: 1:32:10 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1678.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5558/10432 [==============>...............] - ETA: 1:32:09 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1679.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5559/10432 [==============>...............] - ETA: 1:32:08 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1680.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5560/10432 [==============>...............] - ETA: 1:32:07 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1681.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5561/10432 [==============>...............] - ETA: 1:32:06 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1682.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5562/10432 [==============>...............] - ETA: 1:32:04 - loss: 0.0492 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1683.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5563/10432 [==============>...............] - ETA: 1:32:03 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1684.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5564/10432 [===============>..............] - ETA: 1:32:02 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1685.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5565/10432 [===============>..............] - ETA: 1:32:01 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1686.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5566/10432 [===============>..............] - ETA: 1:32:00 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1687.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5567/10432 [===============>..............] - ETA: 1:31:59 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1688.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5568/10432 [===============>..............] - ETA: 1:31:58 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1689.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5569/10432 [===============>..............] - ETA: 1:31:56 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1690.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5570/10432 [===============>..............] - ETA: 1:31:55 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1691.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5571/10432 [===============>..............] - ETA: 1:31:54 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1692.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5572/10432 [===============>..............] - ETA: 1:31:53 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1693.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5573/10432 [===============>..............] - ETA: 1:31:52 - loss: 0.0491 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1694.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5574/10432 [===============>..............] - ETA: 1:31:51 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1695.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5575/10432 [===============>..............] - ETA: 1:31:50 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1696.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5576/10432 [===============>..............] - ETA: 1:31:49 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1697.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5577/10432 [===============>..............] - ETA: 1:31:47 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1698.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5578/10432 [===============>..............] - ETA: 1:31:46 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1699.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5579/10432 [===============>..............] - ETA: 1:31:45 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1700.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5580/10432 [===============>..............] - ETA: 1:31:44 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1701.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5581/10432 [===============>..............] - ETA: 1:31:43 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1702.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5582/10432 [===============>..............] - ETA: 1:31:42 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1703.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5583/10432 [===============>..............] - ETA: 1:31:41 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1704.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5584/10432 [===============>..............] - ETA: 1:31:40 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1705.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5585/10432 [===============>..............] - ETA: 1:31:39 - loss: 0.0490 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1706.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5586/10432 [===============>..............] - ETA: 1:31:38 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1707.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5587/10432 [===============>..............] - ETA: 1:31:37 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1708.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5588/10432 [===============>..............] - ETA: 1:31:36 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1709.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5589/10432 [===============>..............] - ETA: 1:31:35 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1710.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5590/10432 [===============>..............] - ETA: 1:31:34 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1711.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5591/10432 [===============>..............] - ETA: 1:31:33 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1712.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5592/10432 [===============>..............] - ETA: 1:31:32 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1713.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5593/10432 [===============>..............] - ETA: 1:31:30 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1714.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5594/10432 [===============>..............] - ETA: 1:31:29 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1715.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5595/10432 [===============>..............] - ETA: 1:31:28 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1716.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5596/10432 [===============>..............] - ETA: 1:31:27 - loss: 0.0489 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1717.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5597/10432 [===============>..............] - ETA: 1:31:26 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1718.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5598/10432 [===============>..............] - ETA: 1:31:25 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9984 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1719.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5599/10432 [===============>..............] - ETA: 1:31:24 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9985 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1720.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5600/10432 [===============>..............] - ETA: 1:31:23 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9985 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1721.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5601/10432 [===============>..............] - ETA: 1:31:22 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9985 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1722.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5602/10432 [===============>..............] - ETA: 1:31:21 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9985 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1723.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5603/10432 [===============>..............] - ETA: 1:31:19 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9985 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1724.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5604/10432 [===============>..............] - ETA: 1:31:18 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9985 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1725.0000 - false_positives: 4.0000 - false_negatives: 5.0000
#  5605/10432 [===============>..............] - ETA: 1:31:17 - loss: 0.0488 - Accuracy: 0.9984 - auc: 0.9985 - precision: 0.9990 - recall: 0.9987 - true_positives: 3870.0000 - true_negatives: 1726.0000 - false_positives: 4.0000 - false_negatives: 5.0000
# ...
# 10380/10432 [============================>.] - ETA: 59s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7689.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10381/10432 [============================>.] - ETA: 58s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7690.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10382/10432 [============================>.] - ETA: 57s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7691.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10383/10432 [============================>.] - ETA: 56s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7692.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10384/10432 [============================>.] - ETA: 55s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7693.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10385/10432 [============================>.] - ETA: 54s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7694.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10386/10432 [============================>.] - ETA: 52s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7695.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10387/10432 [============================>.] - ETA: 51s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7696.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10388/10432 [============================>.] - ETA: 50s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7697.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10389/10432 [============================>.] - ETA: 49s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7698.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10390/10432 [============================>.] - ETA: 48s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7699.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10391/10432 [============================>.] - ETA: 47s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7700.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10392/10432 [============================>.] - ETA: 45s - loss: 0.0372 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7701.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10393/10432 [============================>.] - ETA: 44s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7702.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10394/10432 [============================>.] - ETA: 43s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7703.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10395/10432 [============================>.] - ETA: 42s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7704.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10396/10432 [============================>.] - ETA: 41s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7705.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10397/10432 [============================>.] - ETA: 40s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7706.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10398/10432 [============================>.] - ETA: 39s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7707.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10399/10432 [============================>.] - ETA: 37s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7708.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10400/10432 [============================>.] - ETA: 36s - loss: 0.0371 - Accuracy: 0.9987 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7709.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10401/10432 [============================>.] - ETA: 35s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7710.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10402/10432 [============================>.] - ETA: 34s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7711.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10403/10432 [============================>.] - ETA: 33s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7712.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10404/10432 [============================>.] - ETA: 32s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7713.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10405/10432 [============================>.] - ETA: 31s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7714.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10406/10432 [============================>.] - ETA: 29s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7715.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10407/10432 [============================>.] - ETA: 28s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7716.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10408/10432 [============================>.] - ETA: 27s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7717.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10409/10432 [============================>.] - ETA: 26s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7718.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10410/10432 [============================>.] - ETA: 25s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7719.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10411/10432 [============================>.] - ETA: 24s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7720.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10412/10432 [============================>.] - ETA: 22s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7721.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10413/10432 [============================>.] - ETA: 21s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7722.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10414/10432 [============================>.] - ETA: 20s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7723.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10415/10432 [============================>.] - ETA: 19s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7724.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10416/10432 [============================>.] - ETA: 18s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7725.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10417/10432 [============================>.] - ETA: 17s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7726.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10418/10432 [============================>.] - ETA: 16s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7727.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10419/10432 [============================>.] - ETA: 14s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7728.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10420/10432 [============================>.] - ETA: 13s - loss: 0.0371 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7729.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10421/10432 [============================>.] - ETA: 12s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7730.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10422/10432 [============================>.] - ETA: 11s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7731.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10423/10432 [============================>.] - ETA: 10s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7732.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10424/10432 [============================>.] - ETA: 9s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7733.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10425/10432 [============================>.] - ETA: 8s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7734.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10426/10432 [============================>.] - ETA: 6s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7735.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10427/10432 [============================>.] - ETA: 5s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7736.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10428/10432 [============================>.] - ETA: 4s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7737.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10429/10432 [============================>.] - ETA: 3s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7738.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10430/10432 [============================>.] - ETA: 2s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7739.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10431/10432 [============================>.] - ETA: 1s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7740.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# (pid=5233) 2022-02-22 21:30:33.306642: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_1"
# (pid=5233) op: "TensorSliceDataset"
# (pid=5233) input: "Placeholder/_0"
# (pid=5233) attr {
# (pid=5233)   key: "Toutput_types"
# (pid=5233)   value {
# (pid=5233)     list {
# (pid=5233)       type: DT_STRING
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "_cardinality"
# (pid=5233)   value {
# (pid=5233)     i: 16
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "is_files"
# (pid=5233)   value {
# (pid=5233)     b: false
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "metadata"
# (pid=5233)   value {
# (pid=5233)     s: "\n\025TensorSliceDataset:10"
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "output_shapes"
# (pid=5233)   value {
# (pid=5233)     list {
# (pid=5233)       shape {
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) experimental_type {
# (pid=5233)   type_id: TFT_PRODUCT
# (pid=5233)   args {
# (pid=5233)     type_id: TFT_DATASET
# (pid=5233)     args {
# (pid=5233)       type_id: TFT_PRODUCT
# (pid=5233)       args {
# (pid=5233)         type_id: TFT_TENSOR
# (pid=5233)         args {
# (pid=5233)           type_id: TFT_STRING
# (pid=5233)         }
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233)   args {
# (pid=5233)     type_id: TFT_DATASET
# (pid=5233)     args {
# (pid=5233)       type_id: TFT_PRODUCT
# (pid=5233)       args {
# (pid=5233)         type_id: TFT_TENSOR
# (pid=5233)         args {
# (pid=5233)           type_id: TFT_STRING
# (pid=5233)         }
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233)
# (pid=5233) 2022-02-22 21:30:33.427415: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 10432/10432 [==============================] - ETA: 0s - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7741.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000
# 10432/10432 [==============================] - 12032s 1s/step - loss: 0.0370 - Accuracy: 0.9988 - auc: 0.9989 - precision: 0.9995 - recall: 0.9988 - true_positives: 7741.0000 - true_negatives: 2678.0000 - false_positives: 4.0000 - false_negatives: 9.0000 - val_loss: 224.1225 - val_Accuracy: 0.5000 - val_auc: 0.5156 - val_precision: 0.5000 - val_recall: 1.0000 - val_true_positives: 16.0000 - val_true_negatives: 0.0000e+00 - val_false_positives: 16.0000 - val_false_negatives: 0.0000e+00

# %% [markdown]
# # Step 5: Evaluate and save the model

# %%
stats = est.evaluate(test_data_creator, num_steps=40)
print(stats)
# Out:
# (pid=5233) Found 624 files belonging to 2 classes.
# (pid=5233) WARNING:tensorflow:AutoGraph could not transform <function test_data_creator.<locals>.<lambda> at 0x7f71f6f0add0> and will run it as-is.
# (pid=5233) Cause: could not parse the source code of <function test_data_creator.<locals>.<lambda> at 0x7f71f6f0add0>: no matching AST found among candidates:
# (pid=5233)
# (pid=5233) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=5233) WARNING:tensorflow:AutoGraph could not transform <function test_data_creator.<locals>.<lambda> at 0x7f71f6f0acb0> and will run it as-is.
# (pid=5233) Cause: could not parse the source code of <function test_data_creator.<locals>.<lambda> at 0x7f71f6f0acb0>: no matching AST found among candidates:
# (pid=5233)
# (pid=5233) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=5233) 2022-02-22 21:30:47.843452: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_1"
# (pid=5233) op: "TensorSliceDataset"
# (pid=5233) input: "Placeholder/_0"
# (pid=5233) attr {
# (pid=5233)   key: "Toutput_types"
# (pid=5233)   value {
# (pid=5233)     list {
# (pid=5233)       type: DT_STRING
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "_cardinality"
# (pid=5233)   value {
# (pid=5233)     i: 624
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "is_files"
# (pid=5233)   value {
# (pid=5233)     b: false
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "metadata"
# (pid=5233)   value {
# (pid=5233)     s: "\n\025TensorSliceDataset:60"
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) attr {
# (pid=5233)   key: "output_shapes"
# (pid=5233)   value {
# (pid=5233)     list {
# (pid=5233)       shape {
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233) experimental_type {
# (pid=5233)   type_id: TFT_PRODUCT
# (pid=5233)   args {
# (pid=5233)     type_id: TFT_DATASET
# (pid=5233)     args {
# (pid=5233)       type_id: TFT_PRODUCT
# (pid=5233)       args {
# (pid=5233)         type_id: TFT_TENSOR
# (pid=5233)         args {
# (pid=5233)           type_id: TFT_STRING
# (pid=5233)         }
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233)   args {
# (pid=5233)     type_id: TFT_DATASET
# (pid=5233)     args {
# (pid=5233)       type_id: TFT_PRODUCT
# (pid=5233)       args {
# (pid=5233)         type_id: TFT_TENSOR
# (pid=5233)         args {
# (pid=5233)           type_id: TFT_STRING
# (pid=5233)         }
# (pid=5233)       }
# (pid=5233)     }
# (pid=5233)   }
# (pid=5233) }
# (pid=5233)
#  1/40 [..............................] - ETA: 5:31 - loss: 79.1359 - Accuracy: 0.6250 - auc: 0.5979 - precision: 0.6250 - recall: 1.0000 - true_positives: 20.0000 - true_negatives: 0.0000e+00 - false_positives: 12.0000 - false_negatives: 0.0000e+00
#  2/40 [>.............................] - ETA: 3:36 - loss: 91.5013 - Accuracy: 0.6094 - auc: 0.4923 - precision: 0.6094 - recall: 1.0000 - true_positives: 39.0000 - true_negatives: 0.0000e+00 - false_positives: 25.0000 - false_negatives: 0.0000e+00
#  3/40 [=>............................] - ETA: 3:32 - loss: 104.1209 - Accuracy: 0.6354 - auc: 0.4787 - precision: 0.6354 - recall: 1.0000 - true_positives: 61.0000 - true_negatives: 0.0000e+00 - false_positives: 35.0000 - false_negatives: 0.0000e+00
#  4/40 [==>...........................] - ETA: 3:28 - loss: 101.9827 - Accuracy: 0.6016 - auc: 0.5027 - precision: 0.5984 - recall: 1.0000 - true_positives: 76.0000 - true_negatives: 1.0000 - false_positives: 51.0000 - false_negatives: 0.0000e+00
#  5/40 [==>...........................] - ETA: 3:23 - loss: 107.4973 - Accuracy: 0.5938 - auc: 0.5222 - precision: 0.5912 - recall: 1.0000 - true_positives: 94.0000 - true_negatives: 1.0000 - false_positives: 65.0000 - false_negatives: 0.0000e+00
#  6/40 [===>..........................] - ETA: 3:16 - loss: 114.8764 - Accuracy: 0.5938 - auc: 0.5286 - precision: 0.5916 - recall: 1.0000 - true_positives: 113.0000 - true_negatives: 1.0000 - false_positives: 78.0000 - false_negatives: 0.0000e+00
#  7/40 [====>.........................] - ETA: 3:09 - loss: 110.3113 - Accuracy: 0.6071 - auc: 0.5202 - precision: 0.6054 - recall: 1.0000 - true_positives: 135.0000 - true_negatives: 1.0000 - false_positives: 88.0000 - false_negatives: 0.0000e+00
#  8/40 [=====>........................] - ETA: 3:03 - loss: 108.5435 - Accuracy: 0.6133 - auc: 0.5012 - precision: 0.6118 - recall: 1.0000 - true_positives: 156.0000 - true_negatives: 1.0000 - false_positives: 99.0000 - false_negatives: 0.0000e+00
#  9/40 [=====>........................] - ETA: 2:56 - loss: 107.3278 - Accuracy: 0.6215 - auc: 0.4930 - precision: 0.6202 - recall: 1.0000 - true_positives: 178.0000 - true_negatives: 1.0000 - false_positives: 109.0000 - false_negatives: 0.0000e+00
# 10/40 [======>.......................] - ETA: 2:50 - loss: 107.4575 - Accuracy: 0.6250 - auc: 0.4935 - precision: 0.6238 - recall: 1.0000 - true_positives: 199.0000 - true_negatives: 1.0000 - false_positives: 120.0000 - false_negatives: 0.0000e+00
# 11/40 [=======>......................] - ETA: 2:44 - loss: 110.8092 - Accuracy: 0.6136 - auc: 0.5033 - precision: 0.6125 - recall: 1.0000 - true_positives: 215.0000 - true_negatives: 1.0000 - false_positives: 136.0000 - false_negatives: 0.0000e+00
# 12/40 [========>.....................] - ETA: 2:38 - loss: 109.0229 - Accuracy: 0.6146 - auc: 0.5063 - precision: 0.6136 - recall: 1.0000 - true_positives: 235.0000 - true_negatives: 1.0000 - false_positives: 148.0000 - false_negatives: 0.0000e+00
# 13/40 [========>.....................] - ETA: 2:32 - loss: 109.8183 - Accuracy: 0.6130 - auc: 0.5040 - precision: 0.6120 - recall: 1.0000 - true_positives: 254.0000 - true_negatives: 1.0000 - false_positives: 161.0000 - false_negatives: 0.0000e+00
# 14/40 [=========>....................] - ETA: 2:26 - loss: 111.9376 - Accuracy: 0.6094 - auc: 0.4964 - precision: 0.6085 - recall: 1.0000 - true_positives: 272.0000 - true_negatives: 1.0000 - false_positives: 175.0000 - false_negatives: 0.0000e+00
# 15/40 [==========>...................] - ETA: 2:20 - loss: 105.6263 - Accuracy: 0.6271 - auc: 0.5028 - precision: 0.6263 - recall: 1.0000 - true_positives: 300.0000 - true_negatives: 1.0000 - false_positives: 179.0000 - false_negatives: 0.0000e+00
# 16/40 [===========>..................] - ETA: 2:15 - loss: 103.5552 - Accuracy: 0.6289 - auc: 0.5020 - precision: 0.6282 - recall: 1.0000 - true_positives: 321.0000 - true_negatives: 1.0000 - false_positives: 190.0000 - false_negatives: 0.0000e+00
# 17/40 [===========>..................] - ETA: 2:10 - loss: 106.6822 - Accuracy: 0.6195 - auc: 0.5042 - precision: 0.6188 - recall: 1.0000 - true_positives: 336.0000 - true_negatives: 1.0000 - false_positives: 207.0000 - false_negatives: 0.0000e+00
# 18/40 [============>.................] - ETA: 2:04 - loss: 107.0681 - Accuracy: 0.6215 - auc: 0.4997 - precision: 0.6209 - recall: 1.0000 - true_positives: 357.0000 - true_negatives: 1.0000 - false_positives: 218.0000 - false_negatives: 0.0000e+00
# 19/40 [=============>................] - ETA: 1:58 - loss: 104.2425 - Accuracy: 0.6250 - auc: 0.5064 - precision: 0.6244 - recall: 1.0000 - true_positives: 379.0000 - true_negatives: 1.0000 - false_positives: 228.0000 - false_negatives: 0.0000e+00
# 20/40 [==============>...............] - ETA: 1:50 - loss: 104.9765 - Accuracy: 0.6266 - auc: 0.5042 - precision: 0.6260 - recall: 1.0000 - true_positives: 390.0000 - true_negatives: 1.0000 - false_positives: 233.0000 - false_negatives: 0.0000e+00
# 21/40 [==============>...............] - ETA: 1:44 - loss: 105.2499 - Accuracy: 0.6235 - auc: 0.5042 - precision: 0.6229 - recall: 1.0000 - true_positives: 408.0000 - true_negatives: 1.0000 - false_positives: 247.0000 - false_negatives: 0.0000e+00
# 22/40 [===============>..............] - ETA: 1:39 - loss: 107.7401 - Accuracy: 0.6206 - auc: 0.5031 - precision: 0.6201 - recall: 1.0000 - true_positives: 426.0000 - true_negatives: 1.0000 - false_positives: 261.0000 - false_negatives: 0.0000e+00
# 23/40 [================>.............] - ETA: 1:34 - loss: 110.3146 - Accuracy: 0.6167 - auc: 0.4988 - precision: 0.6161 - recall: 1.0000 - true_positives: 443.0000 - true_negatives: 1.0000 - false_positives: 276.0000 - false_negatives: 0.0000e+00
# 24/40 [=================>............] - ETA: 1:28 - loss: 110.2152 - Accuracy: 0.6157 - auc: 0.5045 - precision: 0.6152 - recall: 1.0000 - true_positives: 462.0000 - true_negatives: 1.0000 - false_positives: 289.0000 - false_negatives: 0.0000e+00
# 25/40 [=================>............] - ETA: 1:23 - loss: 108.5655 - Accuracy: 0.6148 - auc: 0.5110 - precision: 0.6143 - recall: 1.0000 - true_positives: 481.0000 - true_negatives: 1.0000 - false_positives: 302.0000 - false_negatives: 0.0000e+00
# 26/40 [==================>...........] - ETA: 1:17 - loss: 109.0239 - Accuracy: 0.6164 - auc: 0.5155 - precision: 0.6160 - recall: 1.0000 - true_positives: 502.0000 - true_negatives: 1.0000 - false_positives: 313.0000 - false_negatives: 0.0000e+00
# 27/40 [===================>..........] - ETA: 1:11 - loss: 108.0580 - Accuracy: 0.6156 - auc: 0.5133 - precision: 0.6151 - recall: 1.0000 - true_positives: 521.0000 - true_negatives: 1.0000 - false_positives: 326.0000 - false_negatives: 0.0000e+00
# 28/40 [====================>.........] - ETA: 1:06 - loss: 106.5108 - Accuracy: 0.6205 - auc: 0.5168 - precision: 0.6196 - recall: 1.0000 - true_positives: 544.0000 - true_negatives: 2.0000 - false_positives: 334.0000 - false_negatives: 0.0000e+00
# 29/40 [====================>.........] - ETA: 1:00 - loss: 105.5122 - Accuracy: 0.6239 - auc: 0.5134 - precision: 0.6231 - recall: 1.0000 - true_positives: 567.0000 - true_negatives: 2.0000 - false_positives: 343.0000 - false_negatives: 0.0000e+00
# 30/40 [=====================>........] - ETA: 55s - loss: 104.5214 - Accuracy: 0.6208 - auc: 0.5152 - precision: 0.6200 - recall: 1.0000 - true_positives: 584.0000 - true_negatives: 2.0000 - false_positives: 358.0000 - false_negatives: 0.0000e+00
# 31/40 [======================>.......] - ETA: 49s - loss: 104.8125 - Accuracy: 0.6199 - auc: 0.5120 - precision: 0.6191 - recall: 1.0000 - true_positives: 603.0000 - true_negatives: 2.0000 - false_positives: 371.0000 - false_negatives: 0.0000e+00
# 32/40 [=======================>......] - ETA: 44s - loss: 103.7003 - Accuracy: 0.6220 - auc: 0.5141 - precision: 0.6213 - recall: 1.0000 - true_positives: 625.0000 - true_negatives: 2.0000 - false_positives: 381.0000 - false_negatives: 0.0000e+00
# 33/40 [=======================>......] - ETA: 38s - loss: 102.5541 - Accuracy: 0.6240 - auc: 0.5095 - precision: 0.6233 - recall: 1.0000 - true_positives: 647.0000 - true_negatives: 2.0000 - false_positives: 391.0000 - false_negatives: 0.0000e+00
# 34/40 [========================>.....] - ETA: 33s - loss: 106.1099 - Accuracy: 0.6194 - auc: 0.5061 - precision: 0.6187 - recall: 1.0000 - true_positives: 662.0000 - true_negatives: 2.0000 - false_positives: 408.0000 - false_negatives: 0.0000e+00
# 35/40 [=========================>....] - ETA: 27s - loss: 105.5156 - Accuracy: 0.6250 - auc: 0.5036 - precision: 0.6243 - recall: 1.0000 - true_positives: 688.0000 - true_negatives: 2.0000 - false_positives: 414.0000 - false_negatives: 0.0000e+00
# 36/40 [==========================>...] - ETA: 22s - loss: 105.5293 - Accuracy: 0.6268 - auc: 0.5038 - precision: 0.6261 - recall: 1.0000 - true_positives: 710.0000 - true_negatives: 2.0000 - false_positives: 424.0000 - false_negatives: 0.0000e+00
# 37/40 [==========================>...] - ETA: 16s - loss: 105.7618 - Accuracy: 0.6267 - auc: 0.5040 - precision: 0.6261 - recall: 1.0000 - true_positives: 730.0000 - true_negatives: 2.0000 - false_positives: 436.0000 - false_negatives: 0.0000e+00
# 38/40 [===========================>..] - ETA: 11s - loss: 105.1661 - Accuracy: 0.6267 - auc: 0.5062 - precision: 0.6260 - recall: 1.0000 - true_positives: 750.0000 - true_negatives: 2.0000 - false_positives: 448.0000 - false_negatives: 0.0000e+00
# 39/40 [============================>.] - ETA: 5s - loss: 105.4211 - Accuracy: 0.6258 - auc: 0.5045 - precision: 0.6252 - recall: 1.0000 - true_positives: 769.0000 - true_negatives: 2.0000 - false_positives: 461.0000 - false_negatives: 0.0000e+00
# 40/40 [==============================] - 221s 5s/step - loss: 104.9765 - Accuracy: 0.6266 - auc: 0.5042 - precision: 0.6260 - recall: 1.0000 - true_positives: 780.0000 - true_negatives: 2.0000 - false_positives: 466.0000 - false_negatives: 0.0000e+00
# {'validation_loss': 104.97650909423828, 'validation_Accuracy': 0.6266025900840759, 'validation_auc': 0.5041639804840088, 'validation_precision': 0.6260032057762146, 'validation_recall': 1.0, 'validation_true_positives': 780.0, 'validation_true_negatives': 2.0, 'validation_false_positives': 466.0, 'validation_false_negatives': 0.0}

# %%
est.save("chest_x_ray.model")
# Out:
# 'chest_x_ray.model'

# %%
est.shutdown()

# %%
# Note: You should call stop_orca_context() when your program finishes.
stop_orca_context()
# Out:
# Stopping orca context

# %% [markdown]
# # Conclusion:
# The accuracy obtained when applying our model based on transfer learning of a ResNet50 in the training set is **99.8%** and a precision of 99.9%. However when we tested it with the test set, we obtained an accuracy of 62.5% and a precision of 62.5%. This seems that our model is highly overfitted. This might be due 2 principal reasons:
#
# 1. The proportion of given data is unbalanced. On the one hand, the consat training data set of 5216 images, which represents 89% of the total data, while the test set consists of 624, that is, 11%. Finally, the total number of validation images is 16, barely 1% of the total. However data partitioning methods which have been suggested in several literatures in the field of Machine learning are 70% for training data, 15% for testing data and the last 15% for validation data [8].
# 2. On the other hand, the proportion of NORMAL and PNEUMONIA samples is not the same. For instance, in the training set we got 1341 normal images and 3875 for pneumonia diagnosis. This represent almost double. Consequently, it is reasonable to think that our model learns better to recognize pneumonia images than normal.
#
# To sum up, if we want to solve this overfitted problem and maintain the presented model, we will need more data or more diversity between them.

# %% [markdown]
# # Global references:
#
# [1] https://www.mountsinai.org/health-library/report/pneumonia
#
# [2] https://analytics-zoo.readthedocs.io/en/latest/doc/Orca/QuickStart/orca-tf2keras-quickstart.html
#
# [3] https://machinelearningmastery.com/transfer-learning-for-deep-learning/
#
# [4] https://arxiv.org/abs/1512.03385
#
# [5] https://viso.ai/deep-learning/resnet-residual-neural-network/
#
# [6] https://analytics-zoo.readthedocs.io/en/latest/doc/Orca/QuickStart/orca-tf2keras-quickstart.html
#
# [7] https://blog.roboflow.com/why-preprocess-augment/#:~:text=Preprocessing%20is%20required%20to%20clean%20image%20data%20for%20model%20input.&text=Adjusting%20existing%20training%20data%20to,collected%20datasets%20may%20be%20small.
#
# [8] https://www.researchgate.net/post/Is-there-an-ideal-ratio-between-a-training-set-and-validation-set-Which-trade-off-would-you-suggest
